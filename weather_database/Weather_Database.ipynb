# %%
# %%
import random
from citipy import citipy
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

import requests
from config import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress

# %%
# generate 1500 random latitude and longitude data as a list of tuples
lats = np.random.uniform(-90.0,90.0,size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)

lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)
print(coordinates[:11])
# Out:
# [(47.613779636615845, 8.665196455499284), (9.970389579363996, -26.16182241660738), (44.951733736307375, -146.57207940603385), (-34.09377784836511, -96.25939044919141), (29.6263709048239, 58.421543724639434), (88.83133379137803, 39.1007122245789), (12.003955796852722, -161.4302241245284), (-39.824128900053076, 112.11470987876788), (83.62140143367253, 164.72077962184323), (-24.535076343013827, 91.87497677343958), (-47.63302226757835, 155.061565004462)]

# %%
# %%
# use citipy module to get nearest city names
cities = list()
for coor in coordinates:
    cities_name = citipy.nearest_city(coor[0], coor[1]).city_name
    # ensure no any duplicate cities
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))

# %%
# use OpenWeather API to request, get, parse JSON to retrieve weather data for each city.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")

# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1 
        set_count +=1
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try: 
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        description = js['weather'][0]['description']
        
        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed, 'Description':description})
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# ['schaffhausen', 'sao filipe', 'kodiak', 'lebu', 'bam', 'vardo', 'ewa beach', 'busselton', 'pevek', 'carnarvon'] Generate 744
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | schaffhausen
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | bam
# Processing Record 6 of Set 1 | vardo
# Processing Record 7 of Set 1 | ewa beach
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | aden
# Processing Record 20 of Set 1 | sheridan
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | linxia
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | moussoro
# Processing Record 27 of Set 1 | shubarshi
# Processing Record 28 of Set 1 | boralday
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | mnogovershinnyy
# Processing Record 31 of Set 1 | paamiut
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | hauterive
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | krasnoselkup
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | bull savanna
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | asau
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | fayaoue
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | wuwei
# Processing Record 2 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 2 | tiarei
# Processing Record 4 of Set 2 | tombouctou
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | angoram
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 2 | sandakan
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | lasa
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | siderno
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | tazovskiy
# Processing Record 20 of Set 2 | kholtoson
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | hernani
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | arman
# Processing Record 25 of Set 2 | kulu
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | bijie
# Processing Record 28 of Set 2 | eyemouth
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | marawi
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | shakawe
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 2 | wanlaweyn
# Processing Record 38 of Set 2 | coquimbo
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | trojes
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | amiens
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | tabou
# Processing Record 48 of Set 2 | prigen
# Processing Record 49 of Set 2 | broome
# Processing Record 50 of Set 2 | diego de almagro
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | nabire
# Processing Record 3 of Set 3 | flinders
# Processing Record 4 of Set 3 | miri
# Processing Record 5 of Set 3 | chardara
# Processing Record 6 of Set 3 | xichang
# Processing Record 7 of Set 3 | carutapera
# Processing Record 8 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 3 | andenes
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | banda aceh
# Processing Record 16 of Set 3 | baykit
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | valparaiso
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | bathsheba
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | waipawa
# Processing Record 23 of Set 3 | norden
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | latung
# Processing Record 27 of Set 3 | outlook
# Processing Record 28 of Set 3 | pokanayevka
# City not found. Skipping...
# Processing Record 29 of Set 3 | podgornoye
# Processing Record 30 of Set 3 | igarka
# Processing Record 31 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | namatanai
# Processing Record 34 of Set 3 | port-gentil
# Processing Record 35 of Set 3 | naze
# Processing Record 36 of Set 3 | griffith
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | alizai
# Processing Record 40 of Set 3 | prainha
# Processing Record 41 of Set 3 | udachnyy
# Processing Record 42 of Set 3 | severo-kurilsk
# Processing Record 43 of Set 3 | port blair
# Processing Record 44 of Set 3 | olafsvik
# Processing Record 45 of Set 3 | touros
# Processing Record 46 of Set 3 | waynesville
# Processing Record 47 of Set 3 | new norfolk
# Processing Record 48 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | ostrovnoy
# Processing Record 1 of Set 4 | ilebo
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | mareeba
# Processing Record 5 of Set 4 | richards bay
# Processing Record 6 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 4 | zhumadian
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | kemijarvi
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | guerrero negro
# Processing Record 12 of Set 4 | pemba
# Processing Record 13 of Set 4 | batagay
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | kawalu
# Processing Record 18 of Set 4 | smyrna
# Processing Record 19 of Set 4 | sur
# Processing Record 20 of Set 4 | alakurtti
# Processing Record 21 of Set 4 | ilhabela
# Processing Record 22 of Set 4 | jiaxing
# Processing Record 23 of Set 4 | caceres
# Processing Record 24 of Set 4 | fairbanks
# Processing Record 25 of Set 4 | devils lake
# Processing Record 26 of Set 4 | sisimiut
# Processing Record 27 of Set 4 | huarmey
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | berlevag
# Processing Record 31 of Set 4 | madimba
# Processing Record 32 of Set 4 | aksum
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | sawakin
# Processing Record 35 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 4 | hobyo
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | vilhena
# Processing Record 39 of Set 4 | gushikawa
# Processing Record 40 of Set 4 | cam ranh
# Processing Record 41 of Set 4 | hirara
# Processing Record 42 of Set 4 | santa isabel do rio negro
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | penzance
# Processing Record 45 of Set 4 | wadi musa
# Processing Record 46 of Set 4 | parbhani
# Processing Record 47 of Set 4 | san miguel
# Processing Record 48 of Set 4 | zeerust
# Processing Record 49 of Set 4 | poya
# Processing Record 50 of Set 4 | tukrah
# Processing Record 1 of Set 5 | dhidhdhoo
# Processing Record 2 of Set 5 | muroto
# Processing Record 3 of Set 5 | matay
# Processing Record 4 of Set 5 | okhotsk
# Processing Record 5 of Set 5 | los llanos de aridane
# Processing Record 6 of Set 5 | hammerfest
# Processing Record 7 of Set 5 | ende
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | christchurch
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | shache
# Processing Record 13 of Set 5 | porto novo
# Processing Record 14 of Set 5 | goba
# Processing Record 15 of Set 5 | rawson
# Processing Record 16 of Set 5 | nova olinda do norte
# Processing Record 17 of Set 5 | inhambane
# Processing Record 18 of Set 5 | evensk
# Processing Record 19 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 5 | maudaha
# Processing Record 21 of Set 5 | labuhan
# Processing Record 22 of Set 5 | esmeraldas
# Processing Record 23 of Set 5 | lavrentiya
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | colomi
# Processing Record 26 of Set 5 | ponta delgada
# Processing Record 27 of Set 5 | bartica
# Processing Record 28 of Set 5 | zhigansk
# Processing Record 29 of Set 5 | paciran
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | hohhot
# Processing Record 33 of Set 5 | fereydun kenar
# Processing Record 34 of Set 5 | assiniboia
# Processing Record 35 of Set 5 | olinda
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | porto empedocle
# Processing Record 38 of Set 5 | chilliwack
# Processing Record 39 of Set 5 | qasigiannguit
# Processing Record 40 of Set 5 | fez
# Processing Record 41 of Set 5 | krasnyy yar
# Processing Record 42 of Set 5 | glens falls
# Processing Record 43 of Set 5 | khani
# Processing Record 44 of Set 5 | souillac
# Processing Record 45 of Set 5 | pangnirtung
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | camacha
# Processing Record 48 of Set 5 | eydhafushi
# Processing Record 49 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | vila franca do campo
# Processing Record 2 of Set 6 | westport
# Processing Record 3 of Set 6 | steamboat springs
# Processing Record 4 of Set 6 | gweta
# Processing Record 5 of Set 6 | portachuelo
# Processing Record 6 of Set 6 | husavik
# Processing Record 7 of Set 6 | pitimbu
# Processing Record 8 of Set 6 | north bend
# Processing Record 9 of Set 6 | esso
# Processing Record 10 of Set 6 | marienburg
# Processing Record 11 of Set 6 | yining
# Processing Record 12 of Set 6 | acurenam
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | marzuq
# Processing Record 15 of Set 6 | novikovo
# Processing Record 16 of Set 6 | nhulunbuy
# Processing Record 17 of Set 6 | kharp
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | batman
# Processing Record 20 of Set 6 | faya
# Processing Record 21 of Set 6 | sa kaeo
# Processing Record 22 of Set 6 | kurgan
# Processing Record 23 of Set 6 | belyy yar
# Processing Record 24 of Set 6 | navolato
# Processing Record 25 of Set 6 | petukhovo
# Processing Record 26 of Set 6 | churapcha
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | elko
# Processing Record 30 of Set 6 | shenzhen
# Processing Record 31 of Set 6 | tambun
# Processing Record 32 of Set 6 | mahenge
# Processing Record 33 of Set 6 | asfi
# Processing Record 34 of Set 6 | chuy
# Processing Record 35 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 6 | yumen
# Processing Record 37 of Set 6 | colares
# Processing Record 38 of Set 6 | hami
# Processing Record 39 of Set 6 | daneasa
# Processing Record 40 of Set 6 | sokoni
# Processing Record 41 of Set 6 | ibra
# Processing Record 42 of Set 6 | brownsville
# Processing Record 43 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 6 | salalah
# Processing Record 45 of Set 6 | sinnamary
# Processing Record 46 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 6 | wuda
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | azare
# Processing Record 50 of Set 6 | berdigestyakh
# Processing Record 1 of Set 7 | trinidad
# Processing Record 2 of Set 7 | kostek
# Processing Record 3 of Set 7 | dingle
# Processing Record 4 of Set 7 | mandalgovi
# Processing Record 5 of Set 7 | mahesana
# Processing Record 6 of Set 7 | moose factory
# Processing Record 7 of Set 7 | college
# Processing Record 8 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 7 | dikson
# Processing Record 10 of Set 7 | sehithwa
# Processing Record 11 of Set 7 | tezu
# Processing Record 12 of Set 7 | atherton
# Processing Record 13 of Set 7 | kondinskoye
# Processing Record 14 of Set 7 | swan hill
# Processing Record 15 of Set 7 | tasiilaq
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | pacific grove
# Processing Record 18 of Set 7 | wawa
# Processing Record 19 of Set 7 | yabrud
# Processing Record 20 of Set 7 | la rioja
# Processing Record 21 of Set 7 | gusinoye ozero
# Processing Record 22 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 7 | saint-francois
# Processing Record 24 of Set 7 | novospasskoye
# Processing Record 25 of Set 7 | santiago de cao
# Processing Record 26 of Set 7 | halifax
# Processing Record 27 of Set 7 | miraflores
# Processing Record 28 of Set 7 | isla vista
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | peleduy
# Processing Record 31 of Set 7 | port lincoln
# Processing Record 32 of Set 7 | amboasary
# Processing Record 33 of Set 7 | encheng
# Processing Record 34 of Set 7 | arlington
# Processing Record 35 of Set 7 | chicla
# Processing Record 36 of Set 7 | katherine
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | charleville-mezieres
# Processing Record 39 of Set 7 | vakhrushev
# Processing Record 40 of Set 7 | marsa matruh
# Processing Record 41 of Set 7 | sibolga
# Processing Record 42 of Set 7 | adre
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | erenhot
# Processing Record 46 of Set 7 | constitucion
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | lewistown
# Processing Record 49 of Set 7 | bilma
# Processing Record 50 of Set 7 | ixtapa
# Processing Record 1 of Set 8 | kathmandu
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | san andres
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | zafra
# Processing Record 6 of Set 8 | byron bay
# Processing Record 7 of Set 8 | fort nelson
# Processing Record 8 of Set 8 | shimoda
# Processing Record 9 of Set 8 | provideniya
# Processing Record 10 of Set 8 | vung tau
# Processing Record 11 of Set 8 | laguna
# Processing Record 12 of Set 8 | turiacu
# Processing Record 13 of Set 8 | verkhnyaya toyma
# Processing Record 14 of Set 8 | nuuk
# Processing Record 15 of Set 8 | alappuzha
# Processing Record 16 of Set 8 | boyolangu
# Processing Record 17 of Set 8 | hinton
# Processing Record 18 of Set 8 | kodinsk
# Processing Record 19 of Set 8 | virginia beach
# Processing Record 20 of Set 8 | cururupu
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | pierre
# Processing Record 23 of Set 8 | leningradskiy
# Processing Record 24 of Set 8 | bodden town
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | denpasar
# Processing Record 27 of Set 8 | darnah
# Processing Record 28 of Set 8 | avera
# Processing Record 29 of Set 8 | coahuayana
# Processing Record 30 of Set 8 | bilibino
# Processing Record 31 of Set 8 | thinadhoo
# Processing Record 32 of Set 8 | jennings
# Processing Record 33 of Set 8 | smithers
# Processing Record 34 of Set 8 | necochea
# Processing Record 35 of Set 8 | cubuk
# Processing Record 36 of Set 8 | lwowek slaski
# Processing Record 37 of Set 8 | anjangaon
# Processing Record 38 of Set 8 | parana
# Processing Record 39 of Set 8 | les herbiers
# Processing Record 40 of Set 8 | nanakuli
# Processing Record 41 of Set 8 | severo-yeniseyskiy
# Processing Record 42 of Set 8 | ambon
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | xingyi
# Processing Record 45 of Set 8 | hereford
# Processing Record 46 of Set 8 | urumqi
# Processing Record 47 of Set 8 | ayan
# Processing Record 48 of Set 8 | nome
# Processing Record 49 of Set 8 | bac lieu
# Processing Record 50 of Set 8 | osoyoos
# Processing Record 1 of Set 9 | kahului
# Processing Record 2 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | lakselv
# Processing Record 5 of Set 9 | sistranda
# Processing Record 6 of Set 9 | parral
# Processing Record 7 of Set 9 | birjand
# Processing Record 8 of Set 9 | fortuna
# Processing Record 9 of Set 9 | ilulissat
# Processing Record 10 of Set 9 | komsomolskiy
# Processing Record 11 of Set 9 | dunedin
# Processing Record 12 of Set 9 | lazaro cardenas
# Processing Record 13 of Set 9 | lawton
# Processing Record 14 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 9 | mitzic
# Processing Record 16 of Set 9 | acari
# Processing Record 17 of Set 9 | palana
# Processing Record 18 of Set 9 | lublin
# Processing Record 19 of Set 9 | zhetybay
# City not found. Skipping...
# Processing Record 20 of Set 9 | sulangan
# Processing Record 21 of Set 9 | sirnak
# Processing Record 22 of Set 9 | worland
# Processing Record 23 of Set 9 | maniitsoq
# Processing Record 24 of Set 9 | lahij
# Processing Record 25 of Set 9 | port hardy
# Processing Record 26 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 9 | nemuro
# Processing Record 28 of Set 9 | lugovskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | groningen
# Processing Record 30 of Set 9 | yulara
# Processing Record 31 of Set 9 | ofaqim
# Processing Record 32 of Set 9 | xai-xai
# Processing Record 33 of Set 9 | santa maria
# Processing Record 34 of Set 9 | teya
# Processing Record 35 of Set 9 | hit
# Processing Record 36 of Set 9 | gizo
# Processing Record 37 of Set 9 | guarapari
# Processing Record 38 of Set 9 | brewster
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | moree
# Processing Record 41 of Set 9 | chokurdakh
# Processing Record 42 of Set 9 | sorland
# Processing Record 43 of Set 9 | sahuaripa
# Processing Record 44 of Set 9 | udalguri
# Processing Record 45 of Set 9 | nishihara
# Processing Record 46 of Set 9 | teahupoo
# Processing Record 47 of Set 9 | trat
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | zlynka
# Processing Record 50 of Set 9 | morrope
# Processing Record 1 of Set 10 | boromo
# Processing Record 2 of Set 10 | talnakh
# Processing Record 3 of Set 10 | muros
# Processing Record 4 of Set 10 | nizhniy kuranakh
# Processing Record 5 of Set 10 | saurimo
# Processing Record 6 of Set 10 | batagay-alyta
# Processing Record 7 of Set 10 | along
# Processing Record 8 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 10 | tamworth
# Processing Record 10 of Set 10 | russellville
# Processing Record 11 of Set 10 | kungurtug
# Processing Record 12 of Set 10 | buala
# Processing Record 13 of Set 10 | maun
# Processing Record 14 of Set 10 | homer
# Processing Record 15 of Set 10 | leh
# Processing Record 16 of Set 10 | kupang
# Processing Record 17 of Set 10 | takoradi
# Processing Record 18 of Set 10 | markova
# Processing Record 19 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 10 | karratha
# Processing Record 21 of Set 10 | havelock
# Processing Record 22 of Set 10 | buchanan
# Processing Record 23 of Set 10 | galdar
# Processing Record 24 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 10 | pervomayskaya
# Processing Record 26 of Set 10 | aklavik
# Processing Record 27 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 10 | akdepe
# Processing Record 29 of Set 10 | egvekinot
# Processing Record 30 of Set 10 | nouadhibou
# Processing Record 31 of Set 10 | haveli
# Processing Record 32 of Set 10 | bengkulu
# Processing Record 33 of Set 10 | padang
# Processing Record 34 of Set 10 | cabangahan
# Processing Record 35 of Set 10 | akom
# Processing Record 36 of Set 10 | nouakchott
# Processing Record 37 of Set 10 | gallup
# Processing Record 38 of Set 10 | la primavera
# Processing Record 39 of Set 10 | grajau
# Processing Record 40 of Set 10 | doume
# Processing Record 41 of Set 10 | hualmay
# Processing Record 42 of Set 10 | tanete
# Processing Record 43 of Set 10 | tall kayf
# Processing Record 44 of Set 10 | harper
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | rovaniemi
# Processing Record 47 of Set 10 | moyale
# Processing Record 48 of Set 10 | northam
# Processing Record 49 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 10 | copiapo
# Processing Record 1 of Set 11 | porgera
# Processing Record 2 of Set 11 | yerbogachen
# Processing Record 3 of Set 11 | pisco
# Processing Record 4 of Set 11 | lima
# Processing Record 5 of Set 11 | santa cruz
# Processing Record 6 of Set 11 | grand gaube
# Processing Record 7 of Set 11 | klaksvik
# Processing Record 8 of Set 11 | koutsouras
# Processing Record 9 of Set 11 | ulaangom
# Processing Record 10 of Set 11 | hunchun
# Processing Record 11 of Set 11 | tucuman
# Processing Record 12 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 11 | san rafael
# Processing Record 14 of Set 11 | kyzyl-suu
# Processing Record 15 of Set 11 | raga
# Processing Record 16 of Set 11 | katima mulilo
# Processing Record 17 of Set 11 | mecca
# Processing Record 18 of Set 11 | kebemer
# City not found. Skipping...
# Processing Record 19 of Set 11 | umm kaddadah
# Processing Record 20 of Set 11 | menongue
# Processing Record 21 of Set 11 | lewiston
# Processing Record 22 of Set 11 | visnes
# Processing Record 23 of Set 11 | san carlos
# Processing Record 24 of Set 11 | velingara
# Processing Record 25 of Set 11 | babstovo
# Processing Record 26 of Set 11 | damara
# Processing Record 27 of Set 11 | jambi
# Processing Record 28 of Set 11 | tselinnoye
# Processing Record 29 of Set 11 | altamirano
# Processing Record 30 of Set 11 | dudinka
# Processing Record 31 of Set 11 | palestina
# Processing Record 32 of Set 11 | itarema
# Processing Record 33 of Set 11 | anekal
# Processing Record 34 of Set 11 | yaan
# Processing Record 35 of Set 11 | oistins
# Processing Record 36 of Set 11 | popondetta
# Processing Record 37 of Set 11 | batticaloa
# Processing Record 38 of Set 11 | hadishahr
# Processing Record 39 of Set 11 | zenzeli
# Processing Record 40 of Set 11 | ecatepec
# Processing Record 41 of Set 11 | sembakung
# Processing Record 42 of Set 11 | upata
# Processing Record 43 of Set 11 | tabory
# Processing Record 44 of Set 11 | correntina
# Processing Record 45 of Set 11 | iranshahr
# Processing Record 46 of Set 11 | dayong
# Processing Record 47 of Set 11 | sao luiz gonzaga
# Processing Record 48 of Set 11 | emirdag
# Processing Record 49 of Set 11 | kisangani
# Processing Record 50 of Set 11 | ukiah
# Processing Record 1 of Set 12 | tigaon
# Processing Record 2 of Set 12 | zaragoza
# Processing Record 3 of Set 12 | surin
# Processing Record 4 of Set 12 | lewisporte
# Processing Record 5 of Set 12 | jacareacanga
# Processing Record 6 of Set 12 | san quintin
# Processing Record 7 of Set 12 | qianguo
# Processing Record 8 of Set 12 | korla
# Processing Record 9 of Set 12 | atar
# Processing Record 10 of Set 12 | the valley
# Processing Record 11 of Set 12 | adrar
# Processing Record 12 of Set 12 | bernardino de campos
# Processing Record 13 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 12 | yueyang
# Processing Record 15 of Set 12 | canto do buriti
# Processing Record 16 of Set 12 | asosa
# Processing Record 17 of Set 12 | camacupa
# Processing Record 18 of Set 12 | jutai
# Processing Record 19 of Set 12 | tansen
# Processing Record 20 of Set 12 | suntar
# Processing Record 21 of Set 12 | chenghai
# Processing Record 22 of Set 12 | saint anthony
# Processing Record 23 of Set 12 | abasolo
# Processing Record 24 of Set 12 | stutterheim
# Processing Record 25 of Set 12 | goure
# Processing Record 26 of Set 12 | ostersund
# Processing Record 27 of Set 12 | arcachon
# Processing Record 28 of Set 12 | tilichiki
# Processing Record 29 of Set 12 | ingham
# Processing Record 30 of Set 12 | raton
# Processing Record 31 of Set 12 | bubaque
# Processing Record 32 of Set 12 | pundaguitan
# Processing Record 33 of Set 12 | yeniseysk
# Processing Record 34 of Set 12 | kloulklubed
# Processing Record 35 of Set 12 | raudeberg
# Processing Record 36 of Set 12 | huaraz
# Processing Record 37 of Set 12 | likasi
# Processing Record 38 of Set 12 | namibe
# Processing Record 39 of Set 12 | emet
# Processing Record 40 of Set 12 | saint-michel-des-saints
# Processing Record 41 of Set 12 | chengalpattu
# Processing Record 42 of Set 12 | mogadishu
# Processing Record 43 of Set 12 | nanyamba
# Processing Record 44 of Set 12 | ishigaki
# Processing Record 45 of Set 12 | mormugao
# Processing Record 46 of Set 12 | wexford
# Processing Record 47 of Set 12 | mayumba
# Processing Record 48 of Set 12 | nelson bay
# Processing Record 49 of Set 12 | mogzon
# Processing Record 50 of Set 12 | jumla
# Processing Record 1 of Set 13 | san policarpo
# Processing Record 2 of Set 13 | tehuacan
# Processing Record 3 of Set 13 | deputatskiy
# Processing Record 4 of Set 13 | challans
# Processing Record 5 of Set 13 | synya
# Processing Record 6 of Set 13 | beringovskiy
# Processing Record 7 of Set 13 | porto walter
# Processing Record 8 of Set 13 | ambilobe
# Processing Record 9 of Set 13 | baisha
# Processing Record 10 of Set 13 | stodolishche
# Processing Record 11 of Set 13 | atbasar
# Processing Record 12 of Set 13 | sao miguel do araguaia
# Processing Record 13 of Set 13 | bonavista
# Processing Record 14 of Set 13 | ugoofaaru
# Processing Record 15 of Set 13 | utete
# Processing Record 16 of Set 13 | hachinohe
# Processing Record 17 of Set 13 | porto-vecchio
# Processing Record 18 of Set 13 | brooks
# Processing Record 19 of Set 13 | banfora
# Processing Record 20 of Set 13 | jadu
# Processing Record 21 of Set 13 | harer
# Processing Record 22 of Set 13 | kargapolye
# City not found. Skipping...
# Processing Record 23 of Set 13 | melsungen
# Processing Record 24 of Set 13 | caruray
# Processing Record 25 of Set 13 | san cristobal
# Processing Record 26 of Set 13 | zyryanka
# Processing Record 27 of Set 13 | aktash
# Processing Record 28 of Set 13 | marondera
# Processing Record 29 of Set 13 | poum
# Processing Record 30 of Set 13 | road town
# Processing Record 31 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 13 | kapoeta
# Processing Record 33 of Set 13 | iisalmi
# Processing Record 34 of Set 13 | maarianhamina
# Processing Record 35 of Set 13 | kaeo
# Processing Record 36 of Set 13 | malinalco
# Processing Record 37 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 38 of Set 13 | bojaya
# City not found. Skipping...
# Processing Record 39 of Set 13 | awbari
# Processing Record 40 of Set 13 | dakar
# Processing Record 41 of Set 13 | sao jose da coroa grande
# Processing Record 42 of Set 13 | ustyuzhna
# Processing Record 43 of Set 13 | abha
# Processing Record 44 of Set 13 | la plata
# Processing Record 45 of Set 13 | celestun
# Processing Record 46 of Set 13 | anju
# Processing Record 47 of Set 13 | skerries
# Processing Record 48 of Set 13 | ondjiva
# Processing Record 49 of Set 13 | suoyarvi
# Processing Record 50 of Set 13 | rybnaya sloboda
# Processing Record 1 of Set 14 | shenjiamen
# Processing Record 2 of Set 14 | svetlyy
# Processing Record 3 of Set 14 | liuzhou
# Processing Record 4 of Set 14 | sackville
# Processing Record 5 of Set 14 | gillette
# Processing Record 6 of Set 14 | zaysan
# Processing Record 7 of Set 14 | baracoa
# Processing Record 8 of Set 14 | tahe
# Processing Record 9 of Set 14 | yenagoa
# Processing Record 10 of Set 14 | maldonado
# Processing Record 11 of Set 14 | kieta
# Processing Record 12 of Set 14 | hemsedal
# Processing Record 13 of Set 14 | laureles
# Processing Record 14 of Set 14 | chara
# Processing Record 15 of Set 14 | gobabis
# Processing Record 16 of Set 14 | manyana
# Processing Record 17 of Set 14 | iquitos
# Processing Record 18 of Set 14 | bairiki
# Processing Record 19 of Set 14 | bonthe
# Processing Record 20 of Set 14 | chapais
# Processing Record 21 of Set 14 | florencia
# Processing Record 22 of Set 14 | zatoka
# Processing Record 23 of Set 14 | wellsford
# Processing Record 24 of Set 14 | paratebueno
# Processing Record 25 of Set 14 | akyab
# Processing Record 26 of Set 14 | jerez
# Processing Record 27 of Set 14 | half moon bay
# Processing Record 28 of Set 14 | marau
# Processing Record 29 of Set 14 | plettenberg bay
# Processing Record 30 of Set 14 | rodrigues alves
# Processing Record 31 of Set 14 | scarborough
# Processing Record 32 of Set 14 | gat
# Processing Record 33 of Set 14 | maturin
# Processing Record 34 of Set 14 | nong kung si
# Processing Record 35 of Set 14 | tautira
# Processing Record 36 of Set 14 | yamada
# Processing Record 37 of Set 14 | grand-santi
# Processing Record 38 of Set 14 | trairi
# Processing Record 39 of Set 14 | atasu
# Processing Record 40 of Set 14 | almaznyy
# Processing Record 41 of Set 14 | koumac
# Processing Record 42 of Set 14 | ndende
# Processing Record 43 of Set 14 | naugarzan
# City not found. Skipping...
# Processing Record 44 of Set 14 | zhanaozen
# Processing Record 45 of Set 14 | ust-kuyga
# Processing Record 46 of Set 14 | perth
# Processing Record 47 of Set 14 | fukue
# Processing Record 48 of Set 14 | balabac
# Processing Record 49 of Set 14 | zile
# Processing Record 50 of Set 14 | paulo afonso
# Processing Record 1 of Set 15 | durgapur
# Processing Record 2 of Set 15 | mocuba
# Processing Record 3 of Set 15 | warrington
# Processing Record 4 of Set 15 | linhai
# Processing Record 5 of Set 15 | primo tapia
# Processing Record 6 of Set 15 | ducheng
# Processing Record 7 of Set 15 | lafiagi
# Processing Record 8 of Set 15 | alice springs
# Processing Record 9 of Set 15 | capelinha
# Processing Record 10 of Set 15 | sironko
# Processing Record 11 of Set 15 | aksarka
# Processing Record 12 of Set 15 | timiryazevskiy
# Processing Record 13 of Set 15 | maxixe
# Processing Record 14 of Set 15 | pinillos
# Processing Record 15 of Set 15 | rio cuarto
# Processing Record 16 of Set 15 | rurrenabaque
# Processing Record 17 of Set 15 | faanui
# Processing Record 18 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 19 of Set 15 | hofn
# Processing Record 20 of Set 15 | samandag
# Processing Record 21 of Set 15 | jinchang
# Processing Record 22 of Set 15 | puerto madryn
# Processing Record 23 of Set 15 | oparino
# Processing Record 24 of Set 15 | anantapur
# Processing Record 25 of Set 15 | walvis bay
# Processing Record 26 of Set 15 | pao de acucar
# Processing Record 27 of Set 15 | ketchikan
# Processing Record 28 of Set 15 | ahuimanu
# Processing Record 29 of Set 15 | mapimi
# Processing Record 30 of Set 15 | makakilo city
# Processing Record 31 of Set 15 | calama
# Processing Record 32 of Set 15 | bowen
# Processing Record 33 of Set 15 | ugra
# Processing Record 34 of Set 15 | prince george
# Processing Record 35 of Set 15 | natal
# Processing Record 36 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 15 | klyuchevskiy
# Processing Record 38 of Set 15 | uyemskiy
# Processing Record 39 of Set 15 | blagoyevo
# Processing Record 40 of Set 15 | port augusta
# Processing Record 41 of Set 15 | beira
# Processing Record 42 of Set 15 | pyay
# Processing Record 43 of Set 15 | auki
# Processing Record 44 of Set 15 | gurgan
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0  schaffhausen      CH  2020-11-11 00:43:48  47.70    8.63     42.01
# 1    sao filipe      CV  2020-11-11 00:43:48  14.90  -24.50     78.85
# 2        kodiak      US  2020-11-11 00:39:17  57.79 -152.41     44.60
# 3          lebu      CL  2020-11-11 00:43:48 -37.62  -73.65     52.23
# 4           bam      IR  2020-11-11 00:43:48  29.11   58.36     52.99
# 5         vardo      NO  2020-11-11 00:43:49  70.37   31.11     37.74
# 6     ewa beach      US  2020-11-11 00:40:19  21.32 -158.01     87.80
# 7     busselton      AU  2020-11-11 00:39:58 -33.65  115.33     54.00
# 8         pevek      RU  2020-11-11 00:43:49  69.70  170.31     21.04
# 9     carnarvon      AU  2020-11-11 00:39:14 -24.87  113.63     68.00
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0       100          90        1.12               fog
# 1        74           0        5.23         clear sky
# 2        75          90       16.11        light rain
# 3        90           0       12.48         clear sky
# 4        55          27        1.83  scattered clouds
# 5        79         100       15.37   overcast clouds
# 6        45          40       11.41  scattered clouds
# 7        87          53        4.03     broken clouds
# 8        96         100       12.86   overcast clouds
# 9        42           7       17.22         clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
